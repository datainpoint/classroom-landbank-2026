# %% [markdown]
# # 土地銀行數位種子人才發展計劃
#
# > 程式設計基礎與 Python 學習路徑
#
# [郭耀仁](https://hahow.in/@tonykuoyj) | <yaojenkuo@ntu.edu.tw>

# %% [markdown]
# ## 目錄
#
# - 程式設計基本概念（P.3）
# - Python 學習路徑與必要基礎概念（P.10）
# - 個案實作：使用 Python 程式設計實踐「財務自由的世界，財務分析就是一場投資的戰爭」（P.21）
# - 分組討論：檢視小組題目 Python 程式設計的需求（P.71）

# %% [markdown]
# ## 程式設計基本概念

# %% [markdown]
# ## Python 就是圖中的 "Program"
#
# ![](images/data-science-project.png)
#
# 來源：<https://r4ds.had.co.nz/introduction.html>

# %% [markdown]
# ## Python 真的簡單易學？
#
# - 雖然我們可能從很多資訊來源聽到 Python 簡單易學，但是對於初學者而言，Python 程式設計與資料科學是有難度的。
# - 這個難度在 AI 百花齊放的現代有降低。
# - 但是在 Web 2.0 世代（AI 之前）宣稱 Python 簡單易學的聲量就已經相當巨大。

# %% [markdown]
# ## 什麼是程式設計
#
# 以程式語言來指定電腦來解決特定問題的過程，常見的問題包含數值計算、文字搜尋取代、圖像或音訊處理等，程式設計過程包含分析、設計、寫作、測試與除錯等軟體開發的重要步驟。

# %% [markdown]
# ## 什麼是資料科學
#
# 資料科學是一門將資料（Data）提煉為資訊（Information）的學科，提煉過程中可能包含資料載入、資料操作、探索性分析以及監督式學習等。

# %% [markdown]
# ## 初學程式就上手的訣竅
#
# - 選擇一個有興趣的應用情境出發，例如本堂課程採用的金融數據與選股程序。
# - 掌握基礎語法。
# - 掌握不同資料型別的特性。
# - 掌握不同資料結構的特性。
# - 掌握流程控制。
# - 知道如何組織程式碼。

# %% [markdown]
# ## 關於 Python 的二三事
#
# 1. Python 的作者是荷蘭電腦科學家 Guido van Rossum
# 2. Python 的命名源於 Guido van Rossum 非常喜歡電視喜劇 Monty Python's Flying Circus
# 3. Python 的第一版釋出於 1991 年。

# %% [markdown]
# ## Python 學習路徑與必要基礎概念

# %% [markdown]
# ## 怎樣學好 Python
#
# - 找個有興趣的情境。
# - Less is more.
# - 坐而言不如起而行。

# %% [markdown]
# ## 找個有興趣的情境
#
# - 我希望用 Python 作為「使用程式分析金融數據」的語言。
# - 金融數據分析實務上最常面對的資料格式：
#     - CSV（副檔名 `.csv`）
#     - JSON（副檔名 `.json`）
#     - 活頁簿、試算表（副檔名 `.xlsx`）。
#     - 資料庫（副檔名 `.db`）。
# - 從載入、應用這些資料的過程，透過範例學習 Python（Example-based learning）與選股思維。

# %% [markdown]
# ## Less is more
#
# - Python 作為一個泛用（General-purposed）程式語言，功能涵蓋面向非常完整。
# - 將課程內容設計成 Cookbook，而不是 Documentation，避免犯下貪多嚼不爛、蜻蜓點水的錯誤。
# - 「選擇什麼不學」有時候比「選擇要學什麼」更重要。

# %% [markdown]
# ## 坐而言不如起而行
#
# - 採取 Example-based learning 的學習方式，藉由重現課程範例來學習。
# - 跟我過往課程所採取的 Exercise-based learning/Project-based learning 都有異曲同工之妙。
# - 唯有真正動手操作實踐，才能夠確實地學好 Python

# %% [markdown]
# ## 他山之石可以攻錯
#
# > The way R works is pretty straightforward, you apply functions to objects.
# >
# > Greg Martin

# %% [markdown]
# ## 一言以蔽之
#
# > The way Python works is pretty straightforward, you apply functions to objects or you call methods of objects.
# >
# > Yao-Jen Kuo's revision on Greg Martin

# %% [markdown]
# ## 何謂 "apply functions to objects"？
#
# - 在 Python 程式的表達：`function_name(object_name)`
# - 函數（Function）指的是被賦予名稱的運算處理邏輯，能夠完成某一個文字處理或者數值計算，在使用函數之前，必須先確定這個函數在執行的環境中已經被定義妥善。
# - 物件（Object）是一個記憶體位址，這個位址名稱可以作為一個參照。物件可以參照的對象有：資料型別、資料結構、函數、類別與模組。

# %% [markdown]
# ## 何謂 "apply functions to objects"？透過哈囉世界來詮釋
#
# - 物件：`hello_world_string_object`
# - 函數：`print()`
# - 對 `hello_world_string_object` 應用 `print()` 函數。

# %%
hello_world_string_object = "Hello world!"
print(hello_world_string_object)

# %% [markdown]
# ## 何謂 "call methods of objects"？
#
# - 在 Python 程式的表達：`object_name.method_name()`
# - 方法（Method）指的是被綁定在特定類別下的函數，在使用方法之前，必須先確定這個方法所屬的類別有被定義為物件。

# %% [markdown]
# ## 何謂 "call methods of objects"？透過哈囉世界來詮釋
#
# - 物件：`hello_world_string_object`
# - 方法：`upper()`
# - 使用 `hello_world_string_object` 的 `upper()` 方法。

# %%
hello_world_string_object = "Hello world!"
hello_world_string_object.upper()

# %% [markdown]
# ## 個案實作：使用 Python 程式設計實踐「財務自由的世界，財務分析就是一場投資的戰爭」

# %% [markdown]
# ## 初學就上手 Python 的訣竅
#
# - 選擇一個有興趣的應用情境出發，例如本堂課程採用的金融數據與選股程序。
# - 掌握基礎語法。
# - 掌握不同資料型別的特性。
# - 掌握不同資料結構的特性。
# - 掌握流程控制。
# - 知道如何組織程式碼。

# %% [markdown]
# ## 以金融數據為出發點
#
# - 2014 年左右我看了黃國華所著的「財務自由的世界：財務分析就是一場投資的戰爭」一書，對使用程式分析金融數據產生興趣。
# - 彼時我任職 SAS 做 Analytical Consultant，透過 SAS 實作了書中的選股程序。

# %% [markdown]
# ## 工具的更迭演進：SAS、R 語言然後是 Python
#
# - 第一個嘗試透過 SAS 與 Excel 試算表實作，當時 SAS 未有網頁資料擷取的模組，無法納入爬蟲程式。
# - 第二個嘗試透過 R 語言實作，透過 `httr` 與 `rvest` 模組納入爬蟲程式。
# - 第三個嘗試透過 Python，透過 `requests` 與 `BeautifulSoup` 模組納入爬蟲程式。

# %% [markdown]
# ## 無心插柳柳成蔭
#
# - 閱讀黃國華的書籍，讓我開了台灣券商戶，開始投資台股。
# - 閱讀綠角的書籍、部落格以及參與他的講座，則讓我開了美國券商戶，開始投資 Vanguard ETF 與美股。
# - 工作與投資都使用程式分析資料，並且充滿熱情，故而把「講授資料科學語言」當做了自身的志業，從 2017 年至今仍努力 "Stay in the market"

# %% [markdown]
# ## 關於「財務自由的世界：財務分析就是一場投資的戰爭」一書
#
# - 作者：黃國華。
# - 出版社：先覺出版社。
# - 出版日期：2012-10-31
#
# 來源：<https://www.books.com.tw/products/0010562279>

# %% [markdown]
# ## 關於作者
#
# - 專業作家，台大經濟系畢業，歷任外商銀行外匯交易員、中小企銀債券交易員、泛亞銀行襄理、大眾證券自營部副總、創投業合夥人，累積逾 20 年的投資經驗。
# - 暢銷著作：總幹事的投資筆記、交易員的靈魂、收盤後的人生、空手的勇氣、我願意為你解盤、鈔票的重量。
# - 2021 年知名台灣電視劇「茶金」的編劇。

# %% [markdown]
# ## 阿宅師擇股意志之傳承：財務分析上菜的十一道標準程序
#
# 1. 選出上市公司股價前四十名與上櫃公司股價前三十名的公司。
# 2. 丟棄掛牌不到兩年的公司，以及在開曼群島註冊的 F 頭文字股票（現為字尾 -KY）。
# 3. 將過去四年曾經產生虧損的公司剔除掉。
# 4. 剔除過去八季（嚴格一點可挑十二季）其單季營業利益率曾大幅度上下起伏與連續大幅下滑的公司。
# 5. 剔除過去三年累積自由現金流量為負數者。
# 6. 選擇近三個月的合併營收年增率至少要維持正數者。
# 7. 剔除過去三年曾經辦理現金增資的公司。
# 8. 剔除市值50億以下的公司。
# 9. 剔除存貨周轉率連續下滑的公司。
# 10. 剔除成交量過低的公司（總大私房定義：十日均量不能低於自己打算買進部位的十倍）。
# 11. 與惡名昭彰的股市名嘴斷！捨！離！

# %% [markdown]
# ## 為什麼稱作阿宅師上菜的十一道標準程序
#
# - 為什麼叫做「阿宅師擇股意志之傳承：財務分析上菜的十一道標準程序」？
# - 其典故源自於彼時熱門的台灣電影：[總鋪師](https://zh.wikipedia.org/zh-tw/%E7%B8%BD%E8%88%96%E5%B8%AB_(%E9%9B%BB%E5%BD%B1))。
# - 這十一道選股程序源自於作者的舉例、實證研究、經驗與其主張的投資理論，核心精神是「挑選體質良好的上市上櫃公司，而非去預測股價」，可以視為是基本面投資的實踐。

# %% [markdown]
# ## 給定範例金融數據實作阿宅師擇股意志
#
# - 網頁資料擷取（爬蟲程式）所需要的先備知識比較繁雜，需要知道瀏覽器開發者工具、HTTP 請求與結構化/非結構化資料解析...等。
# - 網頁資料擷取（爬蟲程式）的部分我已經先做好，並且整理為實務上最常面對的資料格式：
#     - CSV（副檔名 `.csv`）
#     - JSON（副檔名 `.json`）
#     - 活頁簿、試算表（副檔名 `.xlsx`）。
#     - 資料庫（副檔名 `.db`）。

# %% [markdown]
# ## 免責聲明
#
# - 任何投資行為本身都具備高度風險，作為一個理性投資者，應為其投資決策行為概負全責。
# - 本課程所提供之相關金融數據和內容，均僅供您作為學習 Python 程式語言之輔助參考，並不明示或暗示提供任何擔保或推薦，更不保證所提供之資訊得立即創造獲利或減少損失；對於使用者直接依賴並使用相關資訊後所為之一切投資行為，及其所遭致之直接、間接損失或傷害及相關責任，本課程講師與課程網站恕不負擔任何損害賠償及法律責任。
# - 本課程明確聲明對所有資料之正確性、完整性或妥適性不負任何責任，此包括但不限於：資料中的任何錯誤、缺漏或其他瑕疵、資料之延遲或中斷、或因信任資料而採取的任何行動。又本課程內容均不應被視為投資依據，亦不代表本課程講師與課程網站立場。

# %% [markdown]
# ## 下載資料集
#
# [datasets.zip](https://classroom-hahow-learn-python-with-stock-data.s3.ap-northeast-1.amazonaws.com/datasets.zip)

# %% [markdown]
# ## 掌握基礎語法
#
# - 重要的 Python 參考文件：
#     - 內建函數一覽：<https://docs.python.org/3/library/functions.html>
#     - 標準模組一覽：<https://docs.python.org/3/library/index.html>
#     - 寫作風格：<https://peps.python.org/pep-0008>
#     - 保留字：應用 `help()` 函數於 `"keywords"` 字串。

# %%
string_to_be_helped = "keywords"
help(string_to_be_helped)

# %% [markdown]
# ## 掌握基礎語法（續）
#
# - 如何載入模組並且給予別名。
# - 如何賦値。
# - 如何載入資料。
# - 如何善用 `print()`、`type()`、`len()` 與 `shape` 檢視物件。

# %% [markdown]
# ## 掌握基礎語法：以金融數據 `datasets` 中的 `top_ranking_stocks.csv` 為例

# %%
import pandas as pd

file_path = "top_ranking_stocks.csv"
top_ranking_stocks_csv = pd.read_csv(file_path)
print(type(top_ranking_stocks_csv))
print(top_ranking_stocks_csv.shape)

# %% [markdown]
# ## 掌握基礎語法：以金融數據 `datasets` 中的 `gross_profits_and_operating_margins.json` 為例

# %%
import json

file_path = "gross_profits_and_operating_margins.json"
with open(file_path, "r") as f:
    gross_profits_and_operating_margins_json = json.load(f)

print(type(gross_profits_and_operating_margins_json))
print(len(gross_profits_and_operating_margins_json))

# %% [markdown]
# ## 掌握不同資料型別的特性
#
# - `str`
# - `int`
# - `float`
# - `bool`
# - `None`

# %% [markdown]
# ## 掌握不同資料型別的特性：以金融數據 `datasets` 中的 `gross_profits_and_operating_margins.json` 為例

# %%
the_first_element = gross_profits_and_operating_margins_json[0]
gross_profits_of_the_first_element = list(the_first_element["gross_profit"].values())

print(the_first_element["ticker"])
print(gross_profits_of_the_first_element[0])
print(gross_profits_of_the_first_element[0] <= 0)
print(gross_profits_of_the_first_element[0] > 0)
for data in gross_profits_and_operating_margins_json:
    if data["ticker"] == "00631L.TW":
        print(data)

# %% [markdown]
# ## 掌握不同資料結構的特性
#
# - 內建資料結構
#     - `list`
#     - `tuple`
#     - `dict`
#     - `set`
# - 資料科學資料結構
#     - `ndarray`
#     - `Series`
#     - `DataFrame`

# %% [markdown]
# ## 掌握不同資料結構的特性：以金融數據 `datasets` 中的 `gross_profits_and_operating_margins.json` 為例

# %%
the_first_element = gross_profits_and_operating_margins_json[0]

print(type(gross_profits_and_operating_margins_json))
print(type(the_first_element))
print(the_first_element.keys())
print(the_first_element["ticker"])
print(the_first_element["gross_profit"])
print(the_first_element["gross_profit"].keys())
print(the_first_element["gross_profit"].values())

# %% [markdown]
# ## 掌握不同資料結構的特性：以金融數據 `datasets` 中的 `top_ranking_stocks.csv` 為例

# %%
print(type(top_ranking_stocks_csv))
print(type(top_ranking_stocks_csv.shape))
print(type(top_ranking_stocks_csv["ticker"]))
print(type(top_ranking_stocks_csv["ticker"].values))

# %% [markdown]
# ## 掌握流程控制
#
# - 程式分支
#     - `if`
#     - `if...else...`
#     - `if...elif...else`
# - 迴圈
#     - `for`
#     - `while`

# %% [markdown]
# ## 掌握流程控制：以金融數據 `datasets` 中的 `gross_profits_and_operating_margins.json` 為例

# %%
for data in gross_profits_and_operating_margins_json:
    if data["ticker"] == "00631L.TW":
        print(data)

# %% [markdown]
# ## 知道如何組織程式碼
#
# - 熟練地使用函數/類別/模組。
# - 能夠自行定義函數/類別/模組將可能需要反覆使用的程式碼組織起來。

# %% [markdown]
# ## 如何使用類別/模組整合選股程序
#
# - [stock_filters_by_kuo_hua_huang.py](https://github.com/datainpoint/classroom-hahow-learn-python-with-stock-data/blob/main/stock_filters_by_kuo_hua_huang.py)
# - 在工作目錄必須要有 `stock_filters_by_kuo_hua_huang.py` 以及 `datasets` 中的檔案（可以捨棄 `trading_volumes.xlsx`）。
# - 模組採用的是 `trading_volumes.db` 而不是 `trading_volumes.xlsx`，兩個檔案同樣是交易量，但資料庫因為經過正規化，使用起來較為方便。
#
# ```python
# from stock_filters_by_kuo_hua_huang import StockFilters
#
# stock_filters = StockFilters()
# stock_filters.get_wide_columns()
# stock_filters.get_filtered_stocks()
# ```

# %% [markdown]
# ## 實作一：使用 Python 載入不同副檔名的金融數據
#
# - 使用 Python 載入 CSV：以 `listing_dates.csv` 為例。
# - 使用 Python 載入 JSON：以 `free_cashflows.json` 為例。
# - 使用 Python 載入試算表：以 `trading_volumes.xlsx` 活頁簿的第一個試算表為例。
# - 使用 Python 載入資料庫資料表：以 `trading_volumes.db` 資料庫的 `tickers` 資料表為例。

# %% [markdown]
# ## 實作一使用 Python 載入 CSV 步驟
#
# - 首先將 `listing_dates.csv` 上傳至 Google Colab 的工作目錄。
# - 可以用 Google Colab 的純文字編輯器預覽內容。
# - 載入 `pandas` 模組並且取別名為 `pd`
# - 使用 `pd.read_csv()` 函數載入為 `DataFrame`
# - 以 `DataFrame` 的屬性、方法檢視。

# %% [markdown]
# ```python
# import pandas as pd
#
# file_path = "listing_dates.csv"
# listing_dates_csv = pd.read_csv(file_path)
# print(listing_dates_csv.shape)
# print(listing_dates_csv.head())
# ```

# %% [markdown]
# ## 實作一使用 Python 載入 JSON 步驟
#
# - 首先將 `free_cashflows.json` 上傳至 Google Colab 的工作目錄。
# - 可以用 Google Colab 的純文字編輯器預覽內容。
# - 載入 `json` 模組。
# - 使用 `with` 敘述與 `open()` 函數載入為 Python `list` 或 `dict` 的巢狀資料結構。
# - 以 `print()` 函數檢視。

# %% [markdown]
# ```python
# import json
#
# file_path = "free_cashflows.json"
# with open(file_path, "r") as f:
#     free_cashflows_json = json.load(f)
# print(free_cashflows_json)
# ```

# %% [markdown]
# ## 實作一使用 Python 載入試算表步驟
#
# - 首先將 `trading_volumes.xlsx` 上傳至 Google Colab 的工作目錄。
# - 載入 `pandas` 模組並且取別名為 `pd`
# - 使用 `pd.read_excel()` 函數載入為 `DataFrame`
# - 以 `DataFrame` 的屬性、方法檢視。

# %% [markdown]
# ```python
# import pandas as pd
#
# file_path = "trading_volumes.xlsx"
# trading_volumes_xlsx = pd.read_excel(file_path)
# print(trading_volumes_xlsx.shape)
# print(trading_volumes_xlsx.head())
# ```

# %% [markdown]
# ## 實作一使用 Python 載入資料庫資料表步驟
#
# - 首先將 `trading_volumes.db` 上傳至 Google Colab 的工作目錄。
# - 載入 `sqlite3` 模組。
# - 載入 `pandas` 模組並且取別名為 `pd`
# - 使用 `sqlite3.connect()` 函數建立資料庫連線。
# - 使用 `pd.read_sql()` 函數載入為 `DataFrame`
# - 以 `DataFrame` 的屬性、方法檢視。

# %% [markdown]
# ```python
# import sqlite3
# import pandas as pd
#
# file_path = "trading_volumes.db"
# con = sqlite3.connect(file_path)
# sql_query = "SELECT * FROM tickers;"
# trading_volumes_tickers = pd.read_sql(sql_query, con)
# print(trading_volumes_tickers.shape)
# print(trading_volumes_tickers.head())
# ```

# %% [markdown]
# ## 實作二：剔除資料期間曾經產生虧損的公司
#
# - 使用的金融數據為 `datasets` 中的 `gross_profits_and_operating_margins.json`
# - 金融數據擷取來源：[Yahoo! Finance](https://github.com/ranaroussi/yfinance)

# %% [markdown]
# ## 對於「虧損」的接受度
#
# - 假如我們對於「虧損」的接受度比較寬鬆，意即我不想在這個條件上剔除掉太多公司，可以用「毛利（Gross profit）大於零」定義為沒有虧損。
# - 假如我們對於「虧損」的接受度比較嚴苛，意即我希望在這個條件上盡可能剔除公司，可以用「淨利（Net income）大於零」定義為沒有虧損。
#
# $$
# \text{Gross profit} = \text{Revenue} - \text{Cost of goods sold} \\
# \text{Net income} = \text{Gross profit} - \text{Operating expenses} \\ - \text{Depreciation and amortization} - \text{Taxes and other expenses}
# $$

# %% [markdown]
# ## 使用 Excel 對照實作二

# %% [markdown]
# ## 實作二步驟
#
# - 首先將 `gross_profits_and_operating_margins.json` 上傳至 Google Colab 的工作目錄。
# - 載入 `json` 模組。
# - 使用 `with` 敘述搭配 `json.load()` 函數載入為 `list`
# - 使用 `for` 迴圈走訪 200 個 `dict`。
# - 判斷 `gross_profit` 或 `net_income` 這兩個鍵所對應的多個值中是否有一個小於零（以 `net_income` 為例）。
# - 將判斷結果加總，加總為 0 的紀錄為 `TRUE`，反之紀錄為 `FALSE`，儲存在一個新的 `dict` 之中。

# %% [markdown]
# ```python
# import json
# import numpy as np
#
# file_path = "gross_profits_and_operating_margins.json"
# with open(file_path, "r") as f:
#     gross_profits_and_operating_margins_json = json.load(f)
# ```

# %% [markdown]
# ```python
# is_profitable = list()
# for data in gross_profits_and_operating_margins_json:
#     ticker = data["ticker"]
#     gross_profit = data["gross_profit"]
#     net_income = data["net_income"]
#     if net_income is None:
#         dict_to_append = {
#             "ticker": ticker,
#             "is_profitable": False
#         }
#         is_profitable.append(dict_to_append)
#     else:
#         list_net_income_values = list(net_income.values())
#         arr = np.array(list_net_income_values)
#         arr_is_negative = arr < 0
#         arr_sum = arr_is_negative.sum()
#         dict_to_append = {
#             "ticker": ticker,
#             "is_profitable": not bool(arr_sum)
#         }
#         is_profitable.append(dict_to_append)
# ```

# %% [markdown]
# ## 實作三：剔除資料期間營業利益率連續下滑的公司
#
# - 使用的金融數據為 `datasets` 中的 `gross_profits_and_operating_margins.json`
# - 金融數據擷取來源：[Yahoo! Finance](https://github.com/ranaroussi/yfinance)

# %% [markdown]
# ## 「營業利益率連續下滑」的定義
#
# - 每個資料期間 `t` 的營業利益率都比前一期 `t-1` 還要低。
# - 如果有 `n` 個資料期間，就會有 `n-1` 個差值（$\delta$）。
#
# $$
# \delta_t = \text{Operating margin}_t - \text{Operating margin}_{t-1}
# $$

# %% [markdown]
# ## 使用 Excel 對照實作三

# %% [markdown]
# ## 實作三步驟
#
# - 首先將 `gross_profits_and_operating_margins.json` 上傳至 Google Colab 的工作目錄。
# - 載入 `json` 模組。
# - 使用 `with` 敘述搭配 `json.load()` 函數載入為 `list`
# - 使用 `for` 迴圈走訪 200 個 `dict`。
# - 取出 `operating_margin` 這個鍵所對應的多個值中按照資料期間順序計算差值 $\delta$。
# - 判斷這些差值 $\delta$ 是否大於等於零。
# - 將判斷結果加總，加總為 0 的記錄為 `FALSE`，反之記錄為 `TRUE`，儲存在一個新的 `dict` 之中。

# %% [markdown]
# ```python
# import json
# import numpy as np
#
# file_path = "gross_profits_and_operating_margins.json"
# with open(file_path, "r") as f:
#     gross_profits_and_operating_margins_json = json.load(f)
# ```

# %% [markdown]
# ```python
# is_operating_margin_not_declining = list()
# for data in gross_profits_and_operating_margins_json:
#     ticker = data["ticker"]
#     operating_margin = data["operating_margin"]
#     if operating_margin is None:
#         dict_to_append = {
#             "ticker": ticker,
#             "is_operating_margin_not_declining": False
#         }
#         is_operating_margin_not_declining.append(dict_to_append)
#     else:
#         list_operating_margin_values = list(operating_margin.values())
#         arr = np.array(list_operating_margin_values)
#         arr_reversed = arr[::-1]
#         diff_arr_reversed = np.diff(arr_reversed)
#         arr_is_geq_zero = diff_arr_reversed >= 0
#         arr_sum = arr_is_geq_zero.sum()
#         dict_to_append = {
#             "ticker": ticker,
#             "is_operating_margin_not_declining": bool(arr_sum)
#         }
#         is_operating_margin_not_declining.append(dict_to_append)
# ```

# %% [markdown]
# ## 實作四：使用類別/模組整合選股程序
#
# 使用的金融數據為 `datasets` 中的所有資料。

# %% [markdown]
# ## 實作四步驟
#
# - 首先將 `datasets` 中的資料上傳至 Google Colab 的工作目錄。
# - 載入 `stock_filters_by_kuo_hua_huang` 模組的 `StockFilters` 類別。
# - 初始化 `StockFilters` 類別。
# - 使用 `get_wide_columns()` 方法取得選股標籤。
# - 使用 `get_filtered_stocks()` 方法取得選股結果。

# %% [markdown]
# ```python
# from stock_filters_by_kuo_hua_huang import StockFilters
#
# stock_filters = StockFilters()
# stock_filters.get_wide_columns()
# stock_filters.get_filtered_stocks()
# ```

# %% [markdown]
# ## 分組討論：檢視小組題目 Python 程式設計的需求

# %% [markdown]
# ## 問題解決（Problem solving）的檢核點
#
# - 是否有使用「假說推論樹」後向推導出解題脈絡？
# - 是否有討論出「反直覺、反經驗」的假說？
# - 是否有提出業務的機會點或痛點作為問題來源？
# - 是否有列出關鍵的決策者、利益關係人？
# - 是否有列出問題解決的指標為何？
# - 分析的結果能否對應到行動方案？
# - 是否有列出問題、行動方案的限制為何？
# - 是否有列出可以尋求的支持及資源？

# %% [markdown]
# ## 資料科學框架（Data science pipeline）的檢核點
#
# - 是否已經完成資料來源盤點？
# - Wrangle(資料載入 Import、清理 Tidy、轉換型別或外型 Transform) 是否已經試做？
# - Visualise 資料視覺化是否已經試做？
# - Model 模型是否已經有想法？
# - Program 程式設計是否已經有想法？
# - Communicate 故事是否已經順過脈絡？

# %% [markdown]
# ## 行動方案（Action plan）的檢核點
#
# - 是否有預計的損益表？是否有人力天數的估算？
# - 是否有衡量財務效益與行動難易度，辨識出財務效益高且行動難度低的方案？
# - 是否有列出責任歸屬、時間表與具體步驟？

# %% [markdown]
# ## 成果發表（Presentation）的檢核點
#
# - 是否已經決定簡報人選？
# - 投入與產出不必是 1:1，有沒有評估過小組的槓桿能力？
# - 是否有掌握 80/20 法則？能否把握開頭的 2 分鐘？
# - 是否暸解聽眾的偏好？
# - 是否妥善運用亞里斯多德的溝通三要素？
